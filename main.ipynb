# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading and Understanding data

# %%
df = pd.read_csv("Telco-Customer-Churn.csv")

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7043, step=1)

# %%
df.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 399   5876-QMYLD  Female              0     Yes        Yes      23
# 620   4881-JVQOD    Male              1     Yes        Yes      10
# 4675  7486-KSRVI    Male              0      No         No      43
# 6064  7568-PODML    Male              0      No         No       1
# 4551  5827-MWCZK    Male              0     Yes        Yes      56
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 399           Yes                No              No  No internet service  ...
# 620            No  No phone service             DSL                   No  ...
# 4675          Yes               Yes     Fiber optic                   No  ...
# 6064           No  No phone service             DSL                   No  ...
# 4551          Yes               Yes     Fiber optic                   No  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# # Data Cleaning

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.sample(3)
# Out:
#      customerID gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 204  9142-KZXOP   Male              0      No         No      44          Yes
# 261  3606-TWKGI   Male              1      No         No      13          Yes
# 407  0111-KLBQG   Male              1     Yes        Yes      32          Yes
#
#     MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 204            No     Fiber optic             No  ...               No
# 261           Yes     Fiber optic             No  ...              Yes
# 407            No     Fiber optic             No  ...               No
#
#     TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 204          No          No              No  Month-to-month               No
# 261          No         Yes             Yes  Month-to-month              Yes
# 407          No         Yes             Yes  Month-to-month              Yes
#
# ...

# %%
df["TotalCharges"].head()
# Out:
# 0      29.85
# 1     1889.5
# 2     108.15
# 3    1840.75
# 4     151.65
# Name: TotalCharges, dtype: object

# %%
df["TotalCharges"] = pd.to_numeric(df["TotalCharges"], errors="coerce")

# %%
df["TotalCharges"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7043 entries, 0 to 7042
# Series name: TotalCharges
# Non-Null Count  Dtype
# --------------  -----
# 7032 non-null   float64
# dtypes: float64(1)
# memory usage: 55.2 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
# I need to lower all the columns to look better as some are lowercase, some are uppercase
df.columns = df.columns.str.lower()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   seniorcitizen     7043 non-null   int64
#  3   partner           7043 non-null   object
#  4   dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   phoneservice      7043 non-null   object
#  7   multiplelines     7043 non-null   object
#  8   internetservice   7043 non-null   object
#  9   onlinesecurity    7043 non-null   object
#  10  onlinebackup      7043 non-null   object
#  11  deviceprotection  7043 non-null   object
#  12  techsupport       7043 non-null   object
#  13  streamingtv       7043 non-null   object
#  14  streamingmovies   7043 non-null   object
#  15  contract          7043 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents',
#        'tenure', 'phoneservice', 'multiplelines', 'internetservice',
#        'onlinesecurity', 'onlinebackup', 'deviceprotection', 'techsupport',
#        'streamingtv', 'streamingmovies', 'contract', 'paperlessbilling',
#        'paymentmethod', 'monthlycharges', 'totalcharges', 'churn'],
#       dtype='object')

# %%
df.drop("customerid", axis=1, inplace=True)

# %%
df.head()
# Out:
#    gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       multiplelines internetservice onlinesecurity onlinebackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   deviceprotection techsupport streamingtv streamingmovies        contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
# Conclusion before EDA
# No missing values found.
# No duplicate rows found.
# Data types verified.
# Categorical values inspected.
# All comumn names lowercased
# customerid identified as an identifier and will be removed before modeling.

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.churn.value_counts()
# Out:
# churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df.gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
sns.countplot(x="churn", data=df)
# Out:
# <Axes: xlabel='churn', ylabel='count'>

# %%
sns.histplot(df["tenure"])
# Out:
# <Axes: xlabel='tenure', ylabel='Count'>

# %%
sns.histplot(df["monthlycharges"])
# Out:
# <Axes: xlabel='monthlycharges', ylabel='Count'>

# %%
sns.histplot(df["totalcharges"])
# Out:
# <Axes: xlabel='totalcharges', ylabel='Count'>

# %%
sns.boxplot(x="churn", y="tenure", data=df)
# Out:
# <Axes: xlabel='churn', ylabel='tenure'>

# %%
# this means the ones who stay short leave more

# %%
sns.boxplot(x="churn", y="monthlycharges", data=df)
# Out:
# <Axes: xlabel='churn', ylabel='monthlycharges'>

# %%
sns.countplot(x="contract", hue="churn", data=df)
# Out:
# <Axes: xlabel='contract', ylabel='count'>

# %%
sns.countplot(x="paymentmethod", hue="churn", data=df)
# Out:
# <Axes: xlabel='paymentmethod', ylabel='count'>

# %%
sns.countplot(x="techsupport", hue="churn", data=df)
# Out:
# <Axes: xlabel='techsupport', ylabel='count'>

# %%
corr = df.select_dtypes(include=["number"]).corr()

sns.heatmap(corr, annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
df.head(3)
# Out:
#    gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
#
#       multiplelines internetservice onlinesecurity onlinebackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
#
#   deviceprotection techsupport streamingtv streamingmovies        contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
#
#   paperlessbilling     paymentmethod  monthlycharges  totalcharges churn
# ...

# %%
df_encoded = pd.get_dummies(df, drop_first=True)

corr = df_encoded.corr()

sns.heatmap(corr)
# Out:
# <Axes: >

# %%
# EDA Summary

# - Churned customers are a minority of the dataset.
# - Short-tenure customers are more likely to churn.
# - Month-to-month contracts show higher churn rates.
# - Higher monthly charges appear to be associated with churn.
# - These findings suggest tenure, contract type, and monthly charges may be important predictive features.

# %% [markdown]
# # Feature engineering

# %%
df.sample(3)
# Out:
#       gender  seniorcitizen partner dependents  tenure phoneservice  \
# 2523  Female              0     Yes        Yes      47          Yes
# 3395    Male              0      No         No      62          Yes
# 3199  Female              0      No         No      68          Yes
#
#      multiplelines internetservice       onlinesecurity         onlinebackup  \
# 2523            No              No  No internet service  No internet service
# 3395           Yes     Fiber optic                  Yes                  Yes
# 3199           Yes              No  No internet service  No internet service
#
#          deviceprotection          techsupport          streamingtv  \
# 2523  No internet service  No internet service  No internet service
# 3395                  Yes                   No                   No
# 3199  No internet service  No internet service  No internet service
#
#           streamingmovies        contract paperlessbilling  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   seniorcitizen     7043 non-null   int64
#  2   partner           7043 non-null   object
#  3   dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   phoneservice      7043 non-null   object
#  6   multiplelines     7043 non-null   object
#  7   internetservice   7043 non-null   object
#  8   onlinesecurity    7043 non-null   object
#  9   onlinebackup      7043 non-null   object
#  10  deviceprotection  7043 non-null   object
#  11  techsupport       7043 non-null   object
#  12  streamingtv       7043 non-null   object
#  13  streamingmovies   7043 non-null   object
#  14  contract          7043 non-null   object
#  15  paperlessbilling  7043 non-null   object
# ...

# %%
# handling missing vals

# %%
df.totalcharges.isnull().sum()
# Out:
# np.int64(11)

# %%
df.totalcharges.fillna(0, inplace=True)
# Out:
# C:\Users\OsiyoComputers\AppData\Local\Temp\ipykernel_23776\3162395602.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.totalcharges.fillna(0, inplace=True)

# %%
df.totalcharges.isnull().sum()
# Out:
# np.int64(0)

# %%
# encoding the target column and other needed cols

# %%
df.churn = df.churn.map({"Yes": 1, "No": 0})

# %%
df.gender.isnull().sum()
# Out:
# np.int64(0)

# %%
df.gender = df.gender.map({"Male": 1, "Female": 0})

# %%
df['seniorcitizen'].unique()
# Out:
# array([0, 1])

# %%
# encoding other binary categorical cols

# %%
df.head()
# Out:
#    gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0       0              0     Yes         No       1           No
# 1       1              0      No         No      34          Yes
# 2       1              0      No         No       2          Yes
# 3       1              0      No         No      45           No
# 4       0              0      No         No       2          Yes
#
#       multiplelines internetservice onlinesecurity onlinebackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   deviceprotection techsupport streamingtv streamingmovies        contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['partner', 'dependents', 'phoneservice', 'multiplelines',
#        'internetservice', 'onlinesecurity', 'onlinebackup', 'deviceprotection',
#        'techsupport', 'streamingtv', 'streamingmovies', 'contract',
#        'paperlessbilling', 'paymentmethod'],
#       dtype='object')

# %%
df.head()
# Out:
#    gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0       0              0     Yes         No       1           No
# 1       1              0      No         No      34          Yes
# 2       1              0      No         No       2          Yes
# 3       1              0      No         No      45           No
# 4       0              0      No         No       2          Yes
#
#       multiplelines internetservice onlinesecurity onlinebackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   deviceprotection techsupport streamingtv streamingmovies        contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df_encoded = pd.get_dummies(df, drop_first=True)

# %%
df_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 31 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   gender                                 7043 non-null   int64
#  1   seniorcitizen                          7043 non-null   int64
#  2   tenure                                 7043 non-null   int64
#  3   monthlycharges                         7043 non-null   float64
#  4   totalcharges                           7043 non-null   float64
#  5   churn                                  7043 non-null   int64
#  6   partner_Yes                            7043 non-null   bool
#  7   dependents_Yes                         7043 non-null   bool
#  8   phoneservice_Yes                       7043 non-null   bool
#  9   multiplelines_No phone service         7043 non-null   bool
#  10  multiplelines_Yes                      7043 non-null   bool
# ...

# %%
df_encoded.head(3)
# Out:
#    gender  seniorcitizen  tenure  monthlycharges  totalcharges  churn  \
# 0       0              0       1           29.85         29.85      0
# 1       1              0      34           56.95       1889.50      0
# 2       1              0       2           53.85        108.15      1
#
#    partner_Yes  dependents_Yes  phoneservice_Yes  \
# 0         True           False             False
# 1        False           False              True
# 2        False           False              True
#
#    multiplelines_No phone service  ...  streamingtv_No internet service  \
# 0                            True  ...                            False
# 1                           False  ...                            False
# 2                           False  ...                            False
#
#    streamingtv_Yes  streamingmovies_No internet service  streamingmovies_Yes  \
# 0            False                                False                False
# ...

# %%
# transfer true false boolean into integer so that machine reads true as1 and false as 0
bool_cols = df.select_dtypes(include="bool").columns
df[bool_cols] = df[bool_cols].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   int64
#  1   seniorcitizen     7043 non-null   int64
#  2   partner           7043 non-null   object
#  3   dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   phoneservice      7043 non-null   object
#  6   multiplelines     7043 non-null   object
#  7   internetservice   7043 non-null   object
#  8   onlinesecurity    7043 non-null   object
#  9   onlinebackup      7043 non-null   object
#  10  deviceprotection  7043 non-null   object
#  11  techsupport       7043 non-null   object
#  12  streamingtv       7043 non-null   object
#  13  streamingmovies   7043 non-null   object
#  14  contract          7043 non-null   object
#  15  paperlessbilling  7043 non-null   object
# ...

# %%
# Conclusion
# In feature engineering, missing values were handled and unnecessary columns were removed.
# Binary categorical variables (Yes/No, Male/Female) were converted into 0 and 1 so that machine learning models can interpret them.
# Multi-class categorical variables were encoded into numerical format, and boolean features were converted into integers (0 and 1).
# As a result, the dataset is fully numeric and ready for machine learning model training.

# %% [markdown]
# # Model Training

# %% [markdown]
# ## train-test split

# %%
from sklearn.model_selection import train_test_split

# %%
# Features (input) and target (output)
X = df_encoded.drop('churn', axis=1)
y = df_encoded['churn']

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,      # 20% for testing, 80% for training
    random_state=42     # makes result reproducible
)

# X_train → training features
# X_test → testing features
# y_train → training labels
# y_test → testing labels

# %% [markdown]
# ## train the model

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# C:\Users\OsiyoComputers\anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:473: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000)

# %% [markdown]
# ## predictions

# %%
y_pred = model.predict(X_test)

# %% [markdown]
# ## Evaluation

# %%
# accuracy
from sklearn.metrics import accuracy_score

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8218594748048261

# %%
# confusion matrix 
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_pred))
# Out:
# [[934 102]
#  [149 224]]

# %%
# Classification Report
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88      1036
#            1       0.69      0.60      0.64       373
#
#     accuracy                           0.82      1409
#    macro avg       0.77      0.75      0.76      1409
# weighted avg       0.82      0.82      0.82      1409

# %%
# Probability Predictions
y_proba = model.predict_proba(X_test)

print(y_proba[:5])
# Out:
# [[0.3019536  0.6980464 ]
#  [0.9420391  0.0579609 ]
#  [0.99579459 0.00420541]
#  [0.38537222 0.61462778]
#  [0.9943221  0.0056779 ]]

# %%
# ROC-AUC Score (Professional Metric)
from sklearn.metrics import roc_auc_score

print("ROC-AUC:", roc_auc_score(y_test, model.predict_proba(X_test)[:,1]))
# Out:
# ROC-AUC: 0.862449149647541

# %%
# Feature Importance
feature_importance = pd.DataFrame({
    'feature': X.columns,
    'importance': model.coef_[0]
}).sort_values(by='importance', ascending=False)

print(feature_importance.head(10))
# Out:
#                            feature  importance
# 10     internetservice_Fiber optic    0.642062
# 26            paperlessbilling_Yes    0.337591
# 28  paymentmethod_Electronic check    0.327662
# 8   multiplelines_No phone service    0.276114
# 23             streamingmovies_Yes    0.227167
# 9                multiplelines_Yes    0.220264
# 1                    seniorcitizen    0.162073
# 21                 streamingtv_Yes    0.126057
# 5                      partner_Yes    0.057356
# 3                   monthlycharges    0.002844

# %% [markdown]
# # Evaluation

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88      1036
#            1       0.69      0.60      0.64       373
#
#     accuracy                           0.82      1409
#    macro avg       0.77      0.75      0.76      1409
# weighted avg       0.82      0.82      0.82      1409

# %%
list(X.columns)
# Out:
# ['gender',
#  'seniorcitizen',
#  'tenure',
#  'monthlycharges',
#  'totalcharges',
#  'partner_Yes',
#  'dependents_Yes',
#  'phoneservice_Yes',
#  'multiplelines_No phone service',
#  'multiplelines_Yes',
#  'internetservice_Fiber optic',
#  'internetservice_No',
#  'onlinesecurity_No internet service',
#  'onlinesecurity_Yes',
#  'onlinebackup_No internet service',
#  'onlinebackup_Yes',
#  'deviceprotection_No internet service',
#  'deviceprotection_Yes',
#  'techsupport_No internet service',
#  'techsupport_Yes',
#  'streamingtv_No internet service',
#  'streamingtv_Yes',
#  'streamingmovies_No internet service',
#  'streamingmovies_Yes',
#  'contract_One year',
#  'contract_Two year',
#  'paperlessbilling_Yes',
#  'paymentmethod_Credit card (automatic)',
#  'paymentmethod_Electronic check',
#  'paymentmethod_Mailed check']
